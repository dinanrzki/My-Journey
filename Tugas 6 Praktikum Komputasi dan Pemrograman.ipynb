# %% [markdown]
# <a href="https://colab.research.google.com/github/dinanrzki/My-Journey/blob/main/Tugas%206%20Praktikum%20Komputasi%20dan%20Pemrograman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Metode Jacobi
# Soal Nomor 2

# Tebakan awal
x1 = 0.0
x2 = 0.0
x3 = 0.0

print("Iterasi 0:")
print(f"x1 = {x1:.6f}, x2 = {x2:.6f}, x3 = {x3:.6f}")

for k in range(1, 6):

    x1_baru = (16 - 2*x2 - x3)/5
    x2_baru = (7 - 5*x1 + 2*x3)/6
    x3_baru = (16 + x1 + x2)/4

    print(f"\nIterasi {k}:")
    print(f"x1 = {x1_baru:.6f}")
    print(f"x2 = {x2_baru:.6f}")
    print(f"x3 = {x3_baru:.6f}")

    x1 = x1_baru
    x2 = x2_baru
    x3 = x3_baru

print("\nHasil Iterasi ke-5")
print(f"x1 = {x1:.6f}")
print(f"x2 = {x2:.6f}")
print(f"x3 = {x3:.6f}")
# Out:
# Iterasi 0:
# x1 = 0.000000, x2 = 0.000000, x3 = 0.000000
#
# Iterasi 1:
# x1 = 3.200000
# x2 = 1.166667
# x3 = 4.000000
#
# Iterasi 2:
# x1 = 1.933333
# x2 = -0.166667
# x3 = 5.091667
#
# Iterasi 3:
# x1 = 2.248333
# x2 = 1.252778
# x3 = 4.441667
#
# Iterasi 4:
# x1 = 1.810556
# x2 = 0.773611
# x3 = 4.875278
#
# Iterasi 5:
# x1 = 1.915500
# x2 = 1.282963
# x3 = 4.646042
#
# Hasil Iterasi ke-5
# x1 = 1.915500
# x2 = 1.282963
# x3 = 4.646042
